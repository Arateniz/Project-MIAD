# %%
using MLJ, DataFrames, Plots, UnROOT

# %% [markdown]
# ## read `.root` files

# %%
t = ROOTFile("dane/Data_2018_Xib2XicPi_2018_MD.addVar.wMVA.root")
# Out:
# ROOTFile with 2 entries and 21 streamers.
# dane/Data_2018_Xib2XicPi_2018_MD.addVar.wMVA.root
# └─ mytree (TTree)
#    ├─ "Xb_ENDVERTEX_X"
#    ├─ "Xb_ENDVERTEX_Y"
#    ├─ "Xb_ENDVERTEX_Z"
#    ├─ "⋮"
#    ├─ "pi_PTo"
#    ├─ "pi_Po"
#    └─ "BDTG_Xib"

# %%
mytree = LazyTree(f, )
